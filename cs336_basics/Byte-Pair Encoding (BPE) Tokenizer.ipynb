# %%
chr(0)
# Out:
# '\x00'

# %%
repr(chr(0))
# Out:
# "'\\x00'"

# %%
print(chr(0))

# %%
chr(0)
print(chr(0))
"this is a test" + chr(0) + "string"
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %%
from bpe import train_bpe

vocab, _ = train_bpe("test.txt", 300, ["<|endoftext|>"])
print(vocab[0])  # 应该是 b'\x00'
print(vocab[255])  # 应该是 b'\xff'
print(vocab[256])  # 应该是 b'<|endoftext|>'
# Out:
# b'\x00'
# b'\xff'
# b'<|endoftext|>'
